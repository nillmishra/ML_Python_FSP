# %% [markdown]
# ## Seaborn is a library in python is used for vistullization of the data.
# ## Pandas is the libray in python is used to handele diffrent format of data file like CSV, JSON, HTML, EXCEL

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Write a code to see the the list of data in the seaborn

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ## Write a code to load the dataset which is the seaborn

# %%
tp=sns.load_dataset('tips')

# %% [markdown]
# ## Write a code to display the dataset the dataset in pandas

# %%
tp.head() #it will display the 5 top rows of the dataset
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### write a code to display the information of the datset

# %%
tp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.relplot(x='total_bill', y='tip', data=tp)

# %% [markdown]
# ## Write a code to plot relationship between total_bill and tip

# %% [markdown]
# ## Write a code to check the highest tip gibven by male or female

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', data=tp)

# %% [markdown]
# ## Write a code to display the totak number of male and female in tipsdatset, and visualize also

# %%
tp['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex', data=tp)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### write a code to count day in the tips dataset and also visulize the day of tip dataset

# %%
tp['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
color=['Pink','Orange','Yellow', 'purple']
sns.countplot(x='day', data=tp, palette = color)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ## Write a code to dispaly the count of time and also visulize it

# %%
tp['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.countplot(x='time', data=tp, palette=['green', 'black'])
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %% [markdown]
# ## write a code dispaly the person who given highest tip in a smoker or non smoker

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', style='smoker', data=tp)

# %% [markdown]
# ## write a code to count the no of smoker and non smoker

# %%
tp['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(x='smoker', data=tp, palette=['pink', 'red'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
tp.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', style='smoker', size='size', data=tp)

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', style='smoker', size='size', sizes=(15,200), data=tp)

# %%
tp['tip'].max() #it will return the maximum time value in the dataset
# Out:
# 10.0

# %%
tp['total_bill'].max()
# Out:
# 50.81

# %% [markdown]
# ## write a code to get the mean values of the tip and the toatal bill

# %%
tp['tip'].mean()
# Out:
# 2.99827868852459

# %%
tp['total_bill'].mean()
# Out:
# 19.78594262295082

# %% [markdown]
# ## write a code to get the stats value of he total_bill and tip

# %%
tp[['total_bill','tip']].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %% [markdown]
# ### <font color='cyan'> Line plotting

# %%
sns.relplot(x='sex',y='tip',data=tp,kind='line')

# %% [markdown]
# ### write a code to create a data frame using numpy and pandas

# %%
np.random.seed(0)
df=pd.DataFrame(dict(time=np.arange(500),value=np.random.randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0  1.764052
# 1     1  2.164210
# 2     2  3.142948
# 3     3  5.383841
# 4     4  7.251399

# %%
sns.relplot(x='time',y='value',data=df,kind='line',color='orange')

# %%
df2=pd.DataFrame(np.random.randn(500,2).cumsum(axis=0),columns=['time','value'])
df2
# Out:
#          time      value
# 0    0.382732  -0.034242
# 1    1.479079  -0.268458
# 2    1.131629  -0.849727
# 3   -0.501006  -2.417494
# 4   -1.680164  -1.116066
# ..        ...        ...
# 495  6.062638 -21.434978
# 496  5.497141 -20.958947
# 497  3.339072 -19.640396
# 498  3.099775 -19.887189
# 499  2.020432 -20.001415
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time',y='value',data=df2,kind='line',color='magenta')

# %%
sns.relplot(x='time',y='value',data=df2,kind='line',color='magenta',sort=False)

# %%
flight=sns.load_dataset('flights')
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.relplot(data=flight,x='year',y='passengers',hue='month')

# %%
sns.relplot(data=flight,x='year',y='passengers',hue='month',kind='line')

# %% [markdown]
# ### write a code to display relational plotting of sex and smoker in multiple rows and columns

# %%
sns.relplot(x='total_bill', y='tip',data=tp,hue='sex',row='sex',col='smoker')

# %% [markdown]
# ### write a code to display the catplot of day with tip

# %%
sns.catplot(x='day',y='tip',data=tp)

# %%
sns.catplot(x='day',y='tip',data=tp,jitter=False)

# %% [markdown]
# # swarmplotting

# %%
sns.catplot(x='day',y='tip',data=tp,kind='swarm')
# Out:
# C:\Users\91709\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.catplot(x='day',y='tip',data=tp,kind='swarm')

# %% [markdown]
# ### write a code to display the swarm plotting of day with size

# %%
sns.catplot(x='day',y='tip',data=tp,kind='swarm',hue='size')

# %%
tp[['total_bill','tip']].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %% [markdown]
# ### write a code to display states value in box plot

# %%
sns.catplot(x='day',y='tip',data=tp,kind='box')

# %%
fri=tp[tp['day']=='Fri']

# %%
fri['tip'].describe()
# Out:
# count    19.000000
# mean      2.734737
# std       1.019577
# min       1.000000
# 25%       1.960000
# 50%       3.000000
# 75%       3.365000
# max       4.730000
# Name: tip, dtype: float64

# %%
color=['red','blue','green','yellow']
sns.catplot(x='day',y='tip',data=tp,kind='box',palette=color)

# %%
fri.head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 90       28.97  3.00    Male    Yes  Fri  Dinner     2
# 91       22.49  3.50    Male     No  Fri  Dinner     2
# 92        5.75  1.00  Female    Yes  Fri  Dinner     2
# 93       16.32  4.30  Female    Yes  Fri  Dinner     2
# 94       22.75  3.25  Female     No  Fri  Dinner     2

# %%
sns.catplot(data=fri,x='day',y='tip',kind='box')

# %% [markdown]
# ### write a code to print box plot seperately for male and female

# %%
sns.catplot(data=fri,x='day',y='tip',kind='box',hue='sex')

# %% [markdown]
# # violin plot

# %%
color=['cyan','red','yellow','orange']
sns.catplot(x='day',y='tip',data=tp,kind='violin',palette=color,inner='stick')

# %%
color=['cyan','red','yellow','orange']
sns.catplot(x='day',y='tip',data=tp,kind='violin',palette=color,inner='quartile')

# %% [markdown]
# ### display the diamond data into boxen plot

# %% [markdown]
# ### write a code to display the distribution plotting of the tip dataset

# %%
sns.displot(data=tp,x='total_bill',y='tip',kind='hist')

# %%
sns.displot(data=tp,x='total_bill',kind='hist')

# %% [markdown]
# ### kernel density estimetion

# %%
sns.displot(data=tp,x='total_bill',kind='hist',kde=True)

# %% [markdown]
# ### rug calculating its shows the most crowded data

# %%
sns.displot(data=tp,x='total_bill',kind='hist',kde=True,rug=True)

# %% [markdown]
# ### load dataset of iris and display the pairplot

# %%
i=sns.load_dataset('iris')

# %%
i.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
i['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.pairplot(data=i,hue='species')

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ### operations in pandas

# %%
tp.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ### write a code to check the shape of the data frame of the tip dataset

# %%
tp.shape
# Out:
# (244, 7)

# %% [markdown]
# ### write a code to check complete detail of tip like first highest and 2nd highest

# %%
# let check the index value of the highest and 2nd highest
tp.sort_values(by=['tip'],ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# ..          ...    ...     ...    ...   ...     ...   ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
#
# [244 rows x 7 columns]

# %%
### write  a code to dispaly a particular index values

# %%
tp.loc[tp['tip']==6]
# Out:
#     total_bill  tip   sex smoker  day    time  size
# 47        32.4  6.0  Male     No  Sun  Dinner     4

# %%
### write a code to check the most common value of tip

# %%
tp['tip'].mode()
# Out:
# 0    2.0
# Name: tip, dtype: float64

# %%
tp.loc[tp['tip']==2]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 6          8.77  2.0    Male     No   Sun  Dinner     2
# 26        13.37  2.0    Male     No   Sat  Dinner     2
# 27        12.69  2.0    Male     No   Sat  Dinner     2
# 36        16.31  2.0    Male     No   Sat  Dinner     3
# 61        13.81  2.0    Male    Yes   Sat  Dinner     2
# 86        13.03  2.0    Male     No  Thur   Lunch     2
# 123       15.95  2.0    Male     No  Thur   Lunch     2
# 127       14.52  2.0  Female     No  Thur   Lunch     2
# 128       11.38  2.0  Female     No  Thur   Lunch     2
# 133       12.26  2.0  Female     No  Thur   Lunch     2
# 136       10.33  2.0  Female     No  Thur   Lunch     2
# 137       14.15  2.0  Female     No  Thur   Lunch     2
# 138       16.00  2.0    Male    Yes  Thur   Lunch     2
# 149        7.51  2.0    Male     No  Thur   Lunch     2
# 151       13.13  2.0    Male     No   Sun  Dinner     2
# 153       24.55  2.0    Male     No   Sun  Dinner     4
# ...

# %%
df_2=tp.loc[tp['tip']==2]

# %%
df_2.head()
# Out:
#     total_bill  tip   sex smoker  day    time  size
# 6         8.77  2.0  Male     No  Sun  Dinner     2
# 26       13.37  2.0  Male     No  Sat  Dinner     2
# 27       12.69  2.0  Male     No  Sat  Dinner     2
# 36       16.31  2.0  Male     No  Sat  Dinner     3
# 61       13.81  2.0  Male    Yes  Sat  Dinner     2

# %%
sns.relplot(data=df_2,x='total_bill',y='tip',hue='sex')

# %%
df_2['sex'].value_counts()
# Out:
# Male      22
# Female    11
# Name: sex, dtype: int64

# %%
### write a code to check the top 5 tips value in the tips dataset

# %%
tp['tip'].value_counts().head() # it will return top 5 most tip given
# Out:
# 2.0    33
# 3.0    23
# 4.0    12
# 5.0    10
# 2.5    10
# Name: tip, dtype: int64

# %%
### write a code to check the number of male and female of tip value 3.0

# %%
df_3=tp.loc[tp['tip']==3]

# %%
df_3['sex'].value_counts()
# Out:
# Male      16
# Female     7
# Name: sex, dtype: int64

# %%
### write a code  to find a sample for the number of 2.0

# %%
tp.loc[tp['tip']==2].sample(10)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 6          8.77  2.0    Male     No   Sun  Dinner     2
# 176       17.89  2.0    Male    Yes   Sun  Dinner     2
# 169       10.63  2.0  Female    Yes   Sat  Dinner     2
# 196       10.34  2.0    Male    Yes  Thur   Lunch     2
# 230       24.01  2.0    Male    Yes   Sat  Dinner     4
# 27        12.69  2.0    Male     No   Sat  Dinner     2
# 199       13.51  2.0    Male    Yes  Thur   Lunch     2
# 151       13.13  2.0    Male     No   Sun  Dinner     2
# 240       27.18  2.0  Female    Yes   Sat  Dinner     2
# 153       24.55  2.0    Male     No   Sun  Dinner     4

# %%
### write a code of arranging by sort_values of total_bills with query statement and data should be in the ascending order

# %%
tp.query('tip==2').sort_values(by='total_bill')
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 149        7.51  2.0    Male     No  Thur   Lunch     2
# 6          8.77  2.0    Male     No   Sun  Dinner     2
# 226       10.09  2.0  Female    Yes   Fri   Lunch     2
# 136       10.33  2.0  Female     No  Thur   Lunch     2
# 196       10.34  2.0    Male    Yes  Thur   Lunch     2
# 169       10.63  2.0  Female    Yes   Sat  Dinner     2
# 128       11.38  2.0  Female     No  Thur   Lunch     2
# 133       12.26  2.0  Female     No  Thur   Lunch     2
# 27        12.69  2.0    Male     No   Sat  Dinner     2
# 202       13.00  2.0  Female    Yes  Thur   Lunch     2
# 198       13.00  2.0  Female    Yes  Thur   Lunch     2
# 86        13.03  2.0    Male     No  Thur   Lunch     2
# 151       13.13  2.0    Male     No   Sun  Dinner     2
# 26        13.37  2.0    Male     No   Sat  Dinner     2
# 199       13.51  2.0    Male    Yes  Thur   Lunch     2
# 61        13.81  2.0    Male    Yes   Sat  Dinner     2
# ...

# %%
### write a code to find the record of data which tip value is greater than tip.mean and less than 5

# %%
tp_mean=tp['tip'].mean()
tp_mean
# Out:
# 2.99827868852459

# %%
tp.query('tip>2.99 & tip<5')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [93 rows x 7 columns]

# %%
### downloading of the pokemon dataset

# %%
#reading of the csv file

# %%
po=pd.read_csv('pokemon.csv')
po.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
### write a code to check the name of all columns

# %%
po.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
### write a code to check the pokemon have the attack value more than 150

# %%
po.loc[po['Attack']>150]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 137  127        PinsirMega Pinsir      Bug    Flying    600   65     155
# 141  130    GyaradosMega Gyarados    Water      Dark    640   95     155
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 268  248  TyranitarMega Tyranitar     Rock      Dark    700  100     164
# 279  257    BlazikenMega Blaziken     Fire  Fighting    630   80     160
# 313  289                  Slaking   Normal       NaN    670  150     160
# 387  354      BanetteMega Banette    Ghost       NaN    555   64     165
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 454  409                Rampardos     Rock       NaN    495   97     165
# ...

# %%
po.loc[po['Attack']>150].shape
# Out:
# (18, 13)

# %%
#matplot
plt.figure(figsize=(10,6))
sns.boxplot(data=po,x='Speed')
# Out:
# <Axes: xlabel='Speed'>

# %%
### write a code to select the all pokemon having speed less than 10

# %%
po.loc[po['Speed']<=10].shape
# Out:
# (5, 13)

# %%
po.loc[po['Speed']<=10]
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
po.query('Speed<=10')
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
### write a code to find a pokemon having spcl.def<=25

# %%
po.loc[po['Sp. Def']<=25]
# Out:
#        #                Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 13    10            Caterpie      Bug     NaN    195   45      30       35
# 14    11             Metapod      Bug     NaN    205   50      20       55
# 16    13              Weedle      Bug  Poison    195   40      35       30
# 17    14              Kakuna      Bug  Poison    205   45      25       50
# 44    39          Jigglypuff   Normal   Fairy    270  115      45       20
# 97    90            Shellder    Water     NaN    305   30      65      100
# 106   98              Krabby    Water     NaN    325   30     105       90
# 125  116              Horsea    Water     NaN    295   30      40       70
# 139  129            Magikarp    Water     NaN    200   20      10       55
# 188  174           Igglybuff   Normal   Fairy    210   90      30       15
# 209  194              Wooper    Water  Ground    210   55      45       45
# ...

# %%
po.loc[po['Sp. Def']<=25].count()
# Out:
# #             18
# Name          18
# Type 1        18
# Type 2         6
# Total         18
# HP            18
# Attack        18
# Defense       18
# Sp. Atk       18
# Sp. Def       18
# Speed         18
# Generation    18
# Legendary     18
# dtype: int64

# %%
(po['Sp. Def']<=25).sum()
# Out:
# 18

# %%
### handling of the boolean columns

# %%
po.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
### write a code to display the record of the pokemon having the legendary as True

# %%
po.loc[po['Legendary']]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %%
po.loc[po['Legendary']].shape
# Out:
# (65, 13)

# %%
po.loc[po['Legendary']==False].shape
# Out:
# (735, 13)

# %%
### write a code to find the pokemon that is clearly outliers in terms of attack/defence

# %%
plt.figure(figsize=(10,6))
ax=sns.scatterplot(data=po,x='Defense',y='Attack')
ax.annotate('what plot is saying...>',xy=(228,10),xytext=(150,10),arrowprops=dict(arrowstyle='->',color='Red'))
# Out:
# Text(150, 10, 'what plot is saying...>')

# %%
po.sort_values(by=['Defense','Attack'], ascending=[False,True]).head()
# Out:
#        #                 Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 333  306    AggronMega Aggron  Steel     NaN    630  70     140      230
# 223  208              Steelix  Steel  Ground    510  75      85      200
# 414  377             Regirock   Rock     NaN    580  80     100      200
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230       10      230      5           2      False
# 224       55       95     30           2      False
# 333       60       80     50           3      False
# 223       55       65     30           2      False
# 414       50      100     50           3       True

# %%
tc=sns.load_dataset('titanic')
tc.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# this line will return the output in bool form
tc.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
# this line will print the number of null values present in the dataset
tc.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# this line will display the total no of null having in the dataset
tc.isnull().sum().sum()
# Out:
# 869
